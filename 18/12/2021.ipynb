# %% [markdown]
# <a href="https://colab.research.google.com/github/shiburowin/python/blob/main/18/12/2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([1,2,8,10])
ypoints = np.array([0,5,2,6])
plt.plot(xpoints, ypoints)
plt.show()
